# %% [markdown]
# # Р”Р°РЅРЅС‹Рµ

# %%
import csv
from collections import defaultdict
import random
random.seed(42)

# %%
import numpy as np

def apk(actual, predicted, k=10):
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    if not actual:
        return 0.0

    return score / min(len(actual), k)

# %%
#РЎР»РѕРІР°СЂРё РґР»СЏ РѕСЃРЅРѕРІРЅРѕР№ РІС‹Р±РѕСЂРєРё
user_to_items = defaultdict(set)
item_to_users = defaultdict(set)

#РЎР»РѕРІР°СЂРё РґР»СЏ С‚РµСЃС‚РѕРІРѕР№ РІС‹Р±РѕСЂРєРё
test_user_to_items = defaultdict(set)
test_item_to_users = defaultdict(set)


with open("train_likes.csv") as datafile:
    for like in csv.DictReader(datafile):
        # РљРёРґР°РµРј РјРѕРЅРµС‚РєСѓ. Р’ Р·Р°РІРёСЃРёРјРѕСЃС‚Рё РѕС‚ СЂРµР·СѓР»СЊС‚Р°С‚Р° РєР»Р°РґС‘Рј РІ РѕР±СѓС‡РµРЅРёРµ РёР»Рё С‚РµСЃС‚
        if random.random() < 0.5:
            user_to_items[like['user_id']].add(like['item_id'])
            item_to_users[like['item_id']].add(like['user_id'])
        else:
            test_user_to_items[like['user_id']].add(like['item_id'])
            test_item_to_users[like['item_id']].add(like['user_id'])

# %%
all_items = set(item_to_users.keys()) | set(test_item_to_users.keys())

# %% [markdown]
# # Р¤РёР»СЊС‚СЂР°С†РёСЏ РїРѕР»СЊР·РѕРІР°С‚РµР»РµР№
# * Р—РЅР°С‡РёС‚РµР»СЊРЅР°СЏ С‡Р°СЃС‚СЊ РїРѕР»СЊР·РѕРІР°С‚РµР»РµР№ РёРјРµРµС‚ РІСЃРµРіРѕ 1-2 Р»Р°Р№РєР°. РџСЂРё РІСЃС‘Рј Р¶РµР»Р°РЅРёРё, СЂРµРєРѕРјРјРµРЅРґРѕРІР°С‚СЊ РёРј С‡С‚Рѕ-Р»РёР±Рѕ РѕСЃРјС‹СЃР»РµРЅРЅРѕРµ РїСЂРё РїРѕРјРѕС‰Рё СЂР°СЃСЃРјР°С‚СЂРёРІР°РµРјРѕРіРѕ Р·РґРµСЃСЊ РјРµС‚РѕРґР° РјС‹ РІСЂСЏРґ Р»Рё СЃРјРѕР¶РµРј. Р”Р»СЏ РїСЂРѕСЃС‚РѕС‚С‹ РІС‹С‡РёСЃР»РµРЅРёР№, СѓРґР°Р»РёРј РёС… РёР· РІС‹Р±РѕСЂРєРё.
# * Р’Р°Р¶РЅРѕ РїРѕРЅРёРјР°С‚СЊ, С‡С‚Рѕ РєР°С‡РµСЃС‚РІРѕ РЅР° РѕСЃС‚Р°РІС€РёС…СЃСЏ РїРѕР»СЊР·РѕРІР°С‚РµР»СЏС… СЃРєРѕСЂРµРµ РІСЃРµРіРѕ Р±СѓРґРµС‚ РІС‹С€Рµ, С‡РµРј РЅР° РїРµСЂРІРѕРЅР°С‡Р°Р»СЊРЅРѕР№ РІС‹Р±РѕСЂРєРµ.

# %%
min_items_per_user = 2
from copy import copy
for user in copy(test_user_to_items).keys():
    
    n_items_per_user = len(user_to_items[user]) + len(test_user_to_items[user])
    
    if n_items_per_user <= min_items_per_user:
        del user_to_items[user]
        del test_user_to_items[user]

# %% [markdown]
# ### Р РµРєРѕРјРјРµРЅРґСѓСЋС‰Р°СЏ С„СѓРЅРєС†РёСЏ
# РџРѕР·РІРѕР»РёРј СЃРµР±Рµ РЅРµРјРЅРѕРіРѕ РІРѕР»СЊРЅРѕСЃС‚Рё: РЅР°С€Р° С„СѓРЅРєС†РёСЏ Р±СѓРґРµС‚ РІРѕР·РІСЂР°С‰Р°С‚СЊ РЅРµ РІРµСЂРѕСЏС‚РЅРѕСЃС‚Рё, Р° СЃРїРёСЃРѕРє С„РёР»СЊРјРѕРІ РІ РїРѕСЂСЏРґРєРµ СѓР±С‹РІР°РЅРёСЏ "СЂРµРєРѕРјРµРЅРґРѕРІР°РЅРЅРѕСЃС‚Рё".
#
# * Р РµРєРѕРјРјРµРЅРґРѕРІР°РЅРЅРѕСЃС‚СЊ С„РёР»СЊРјР° item РїРѕР»СЊР·РѕРІР°С‚РµР»СЋ user РїРѕСЃС‡РёС‚Р°РµРј С‚Р°Рє:
#   * Р”Р»СЏ РєР°Р¶РґРѕРіРѕ С„РёР»СЊРјР°, РїРѕР»Р°Р№РєР°РЅРЅРѕРіРѕ РїРѕР»СЊР·РѕРІР°С‚РµР»РµРј user, РЅР°Р№РґС‘Рј РґСЂСѓРіРёС… Р»СЋРґРµР№, РєРѕС‚РѕСЂС‹Рј РїРѕРЅСЂР°РІРёР»СЃСЏ С„РёР»СЊРј.
#   * РЎР»РѕР¶РёРј РІСЃРµС… С‚Р°РєРёС… "РґСЂСѓР·РµР№ РїРѕ Р»Р°Р№РєР°Рј" РІРјРµСЃС‚Рµ Рё РЅР°Р·РѕРІС‘Рј СЃРѕСЃРµРґСЏРјРё (__neighborhood__) РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ.
#   * Р”Р»СЏ С„РёР»СЊРјР° item СѓР·РЅР°РµРј РµРіРѕ Р°СѓРґРёС‚РѕСЂРёСЋ - РјРЅРѕР¶РµСЃС‚РІРѕ РїРѕР»СЊР·РѕРІР°С‚РµР»РµР№, РєРѕС‚РѕСЂС‹Рµ РµРіРѕ Р»Р°Р№РєРЅСѓР»Рё
#   * РџСЂРёРіРѕРґРЅРѕСЃС‚СЊ С„РёР»СЊРјР° РїРѕР»СЊР·РѕРІР°С‚РµР»СЋ - С‚Рѕ, РЅР°СЃРєРѕР»СЊРєРѕ "РґСЂСѓР·СЊСЏРј РїРѕ Р»Р°Р№РєР°Рј" РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ РЅСЂР°РІРёС‚СЃСЏ СЌС‚РѕС‚ С„РёР»СЊРј.
#
# Р”Р»СЏ РїСЂРёРјРµСЂР°, Р±СѓРґРµРј РёСЃРїРѕР»СЊР·РѕРІР°С‚СЊ РєРѕСЃРёРЅСѓСЃРЅСѓСЋ РјРµСЂСѓ СЂР°СЃСЃС‚РѕСЏРЅРёСЏ
#
# $ cos(u_{film}, u_{neighborhood}) = $ =$ u_{film} \cdot u_{neighborhood} \over |u_{film}| |u_{neighborhood}| $
#
#
# $u_{neighborhood}$ Р·Р°РІРёСЃРёС‚ С‚РѕР»СЊРєРѕ РѕС‚ РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ, РЅРѕ РЅРµ РѕС‚ С„РёР»СЊРјР°, РїРѕСЌС‚РѕРјСѓ РїСЂРё СЃСЂР°РІРЅРµРЅРёРё С„РёР»СЊРјРѕРІ РїРѕ РїСЂРёРіРѕРґРЅРѕСЃС‚Рё РґР»СЏ РѕРґРЅРѕРіРѕ РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ, РµРіРѕ РјРѕР¶РЅРѕ РёСЃРєР»СЋС‡РёС‚СЊ РёР· С„РѕСЂРјСѓР»С‹ РґР»СЏ РїСЂРѕСЃС‚РѕС‚С‹ РІС‹С‡РёСЃР»РµРЅРёР№.
#
# $ similarity(u_{film}, u_{neighborhood}) = $ $  u_{film} \cdot u_{neighborhood} \over |u_{film}| $
#
#
# Р Р°СЃРїРёС€РµРј С„РѕСЂРјСѓР»Сѓ РїРѕРґСЂРѕР±РЅРѕ:
#
# $ similarity(u_{film}, u_{neighborhood}) = $ $ \sum _{u_i} [u_i \in u_{film}] \cdot [u_i \in u_{neighborhood}] \over |u_{film}|  $
#
# * u_i - РѕС‡РµСЂРµРґРЅРѕР№ РїРѕР»СЊР·РѕРІР°С‚РµР»СЊ (РІ С†РёРєР»Рµ РїРѕ РІСЃРµРј РїРѕР»СЊР·РѕРІР°С‚РµР»СЏРј)
#
# Р’С‹СЂР°Р¶РµРЅРёРµ $[u_i \in u_neighborhood]$ Р·РґРµСЃСЊ РѕР·РЅР°С‡Р°РµС‚ "СЃРєРѕР»СЊРєРѕ СЂР°Р· РѕС‡РµСЂРµРґРЅРѕР№ РїРѕР»СЊР·РѕРІР°С‚РµР»СЊ РІС…РѕРґРёС‚ РІ РјРЅРѕР¶РµСЃС‚РІРѕ РґСЂСѓР·РµР№ РїРѕ Р»Р°Р№РєР°Рј"

# %%
from math import sqrt
from collections import Counter

def recommend(user, n_best = 10):
    """Р¤СѓРЅРєС†РёСЏ, РєРѕС‚РѕСЂР°СЏ РІРѕР·РІСЂР°С‰Р°РµС‚ СЃРїРёСЃРѕРє СЂРµРєРѕРјРјРµРЅРґРѕРІР°РЅРЅС‹С… С„РёР»СЊРјРѕРІ
    user - id РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ
    n_best - СЃРєРѕР»СЊРєРѕ РјР°РєСЃРёРјСѓРј С„РёР»СЊРјРѕРІ РјРѕР¶РЅРѕ СЂРµРєРѕРјРјРµРЅРґРѕРІР°С‚СЊ
    remove_already_liked - РµСЃР»Рё True, """
    user_items = user_to_items[user]
    
    #СЃРѕСЃРµРґРё РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ {User_id -> СЃРєРѕР»СЊРєРѕ СЂР°Р· СЃРѕСЃРµРґ}
    #Р§С‚Рѕ С‚Р°РєРѕРµ counter - https://pymotw.com/2/collections/counter.html
    neighborhood = Counter()
    for item in user_items:
        neighborhood.update(item_to_users[item])
    
    #СЃР»РѕРІР°СЂСЊ {С„РёР»СЊРј -> РїСЂРёРіРѕРґРЅРѕСЃС‚СЊ С„РёР»СЊРјР° РїРѕР»СЊР·РѕРІР°С‚РµР»СЋ}
    item_similarities = {}
    
    for item in all_items:
        #РїСЂРѕРїСѓСЃС‚РёРј С‚Рµ С„РёР»СЊРјС‹, РєРѕС‚РѕСЂС‹Рµ РїРѕР»СЊР·РѕРІР°С‚РµР»СЊ СѓР¶Рµ Р»Р°Р№РєР°Р», РµСЃР»Рё РЅР°СЃ РѕР± СЌС‚РѕРј РїРѕРїСЂРѕСЃРёР»Рё
        if item in user_items: continue
        
        #РїРѕР»СЊР·РѕРІР°С‚РµР»Рё, Р»Р°Р№РєР°РІС€РёРµ С„РёР»СЊРј item
        item_users = item_to_users[item]
        
        #Р•СЃР»Рё С„РёР»СЊРј РЅРёРєС‚Рѕ РЅРµ Р»Р°Р№РєР°Р», РїСЂРѕРїСѓСЃРєР°РµРј
        if len(item_users) == 0: continue
        
        #С‡РёСЃР»Рѕ СЃРѕСЃРµРґРµР№ user (РєРѕРјСѓ РјС‹ СЂРµРєРѕРјРјРµРЅРґСѓРµРј), Р»Р°Р№РєРЅСѓРІС€РёС… С„РёР»СЊРј item
        n_common_users = sum(neighborhood[user] for user in item_users)
        
        #РїРѕС…РѕР¶РµСЃС‚СЊ РЅР° РёРЅС‚РµСЂРµСЃС‹ РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ = С‡РёСЃР»Рѕ СЃРѕСЃРµРґРµР№, РєРѕРјСѓ РѕРЅ РїРѕРЅСЂР°РІРёР»СЃСЏ, РґРµР»С‘РЅРЅРѕРµ РЅР° РѕР±С‰РµРµ С‡РёСЃР»Рѕ 
        similarity = float(n_common_users) / sqrt(len(item_users))
        
        item_similarities[item] = similarity
    
    #РћС‚СЃРѕСЂС‚РёСЂСѓРµРј РІСЃРµ С„РёР»СЊРјС‹ РїРѕ СѓР±С‹РІР°РЅРёСЋ РёС… РїРѕС…РѕР¶РµСЃС‚Рё РЅР° РёРЅС‚РµСЂРµСЃС‹ РїРѕР»СЊР·РѕРІР°С‚РµР»СЏ
    items_sorted = sorted(all_items, key = lambda x: item_similarities.get(x, 0),reverse = True)
    
    #РІРµСЂРЅС‘Рј n_best РЅР°РёР±РѕР»РµРµ РїСЂРёРіРѕРґРЅС‹С…
    return items_sorted[:n_best]

# %%
# РџРѕСЂРµРєРѕРјРјРµРЅРґСѓРµРј С‚РѕРї-5 С„РёР»СЊРјРѕРІ РєР°РєРѕРјСѓ-С‚Рѕ СЋР·РІРµСЂСЋ
recommend('d8c2794b01531ca807bc2b28d171f22d', n_best=5)
# Out:
# ['e6e53f41066b37fb5b80bd118dc800be',
#  '44327280355abfc1c58fa9ad8c41a2cc',
#  '1e540fdc6ef7c62c3d3ef6d78a6abcab',
#  '13ffc4b8348356546cc44358b6c999c1',
#  'f049e6c94383af7a3c480a7469a5efd4']

# %%
# Р•РјСѓ Р¶Рµ С‚РѕРї-3 С„РёР»СЊРјР°. РЎРѕРІРїР°РґР°РµС‚ СЃ РїРµСЂРІС‹РјРё 3-РјСЏ РёР· С‚РѕРї-5
recommend('d8c2794b01531ca807bc2b28d171f22d', n_best=3)
# Out:
# ['e6e53f41066b37fb5b80bd118dc800be',
#  '44327280355abfc1c58fa9ad8c41a2cc',
#  '1e540fdc6ef7c62c3d3ef6d78a6abcab']

# %% [markdown]
# # РћС†РµРЅРєР° РєР°С‡РµСЃС‚РІР° - map@k

# %%
#СЃРєРѕР»СЊРєРѕ СЂРµРєРѕРјРјРµРЅРґР°С†РёР№ СЂР°СЃСЃРјР°С‚СЂРёРІР°РµРј
K = 10

#РїРѕ РєР°РєРѕР№ С‡Р°СЃС‚Рё С‚РµСЃС‚РѕРІС‹С… РїРѕР»СЊР·РѕРІР°С‚РµР»РµР№ СЃС‡РёС‚Р°РµРј map@k
max_n_users = len(test_user_to_items)
#warnung, РґР»СЏ max_n_users = len(test_user_to_items) С†РёРєР» РјРѕР¶РµС‚ СЃС‡РёС‚Р°С‚СЊСЃСЏ РЅРµСЃРєРѕР»СЊРєРѕ РјРёРЅСѓС‚
#РґР»СЏ РѕС‚Р»Р°РґРєРё СЂРµРєРѕРјРјРµРЅРґСѓРµС‚СЃСЏ РёСЃРїРѕР»СЊР·РѕРІР°С‚СЊ РјРµРЅСЊС€РµРµ С‡РёСЃР»Рѕ


APatK_per_user = []
#РґР»СЏ РІСЃРµС… СЋР·РІРµСЂРµР№
for i, user in enumerate(test_user_to_items):
    
    #С„РёР»СЊРјС‹, РєРѕС‚РѕСЂС‹Рµ РїРѕР»СЊР·РѕРІР°С‚РµР»СЋ РЅР° СЃР°РјРѕРј РґРµР»Рµ РЅСЂР°РІСЏС‚СЃСЏ
    test_items = test_user_to_items[user]
    
    #Р’С‹РґР°С‚СЊ С‚РѕРї-K СЂРµРєРѕРјРјРµРЅРґР°С†РёР№
    recommendation_list = recommend(user,n_best=K)
    
    #РџРѕСЃС‡РёС‚Р°С‚СЊ ap@k
    user_APatK = apk(test_items, recommendation_list,k=K)
    
    #Рё СЃР»РѕР¶РёС‚СЊ РІ РєРѕСЂРѕР±РєСѓ
    APatK_per_user.append(user_APatK)
    
    #Progress bar
    if i % 100 ==0:
        print(i,'/',max_n_users)
        
    if i > max_n_users:
        break
    
print('mAP@{} = {}'.format(K, sum(APatK_per_user)/len(APatK_per_user)))
# Out:
# 0 / 6108
# 100 / 6108
# 200 / 6108
# 300 / 6108
# 400 / 6108
# 500 / 6108
# 600 / 6108
# 700 / 6108
# 800 / 6108
# 900 / 6108
# 1000 / 6108
# 1100 / 6108
# 1200 / 6108
# 1300 / 6108
# 1400 / 6108
# 1500 / 6108
# 1600 / 6108
# 1700 / 6108
# 1800 / 6108
# 1900 / 6108
# 2000 / 6108
# 2100 / 6108
# 2200 / 6108
# 2300 / 6108
# 2400 / 6108
# 2500 / 6108
# 2600 / 6108
# 2700 / 6108
# 2800 / 6108
# 2900 / 6108
# 3000 / 6108
# 3100 / 6108
# 3200 / 6108
# 3300 / 6108
# 3400 / 6108
# 3500 / 6108
# 3600 / 6108
# 3700 / 6108
# 3800 / 6108
# 3900 / 6108
# 4000 / 6108
# 4100 / 6108
# 4200 / 6108
# 4300 / 6108
# 4400 / 6108
# 4500 / 6108
# 4600 / 6108
# 4700 / 6108
# 4800 / 6108
# 4900 / 6108
# 5000 / 6108
# 5100 / 6108
# 5200 / 6108
# 5300 / 6108
# 5400 / 6108
# 5500 / 6108
# 5600 / 6108
# 5700 / 6108
# 5800 / 6108
# 5900 / 6108
# 6000 / 6108
# 6100 / 6108
# mAP@10 = 0.005945258691169598

# %% [markdown]
# # Notes
# * РљСЂРѕРјРµ РєР°С‡РµСЃС‚РІР° СЂРµРєРѕРјРјРµРЅРґР°С†РёР№, map@k РµС‰С‘ Р·Р°РІРёСЃРёС‚ РѕС‚ РґРѕР»Рё С‚РµСЃС‚РѕРІРѕР№ РІС‹Р±РѕСЂРєРё, С„РёР»СЊС‚СЂР°С†РёРё Рё РѕС‚ СЃР°РјРѕРіРѕ K. РЎСЂР°РІРЅРёРІР°С‚СЊ РєР°С‡РµСЃС‚РІРѕ СЂР°Р·РЅС‹С… Р°Р»РіРѕСЂРёС‚РјРѕРІ РёРјРµРµС‚ СЃРјС‹СЃР» С‚РѕР»СЊРєРѕ РїСЂРё РѕРґРёРЅР°РєРѕРІРѕРј K Рё С‚РµСЃС‚РѕРІРѕР№ РІС‹Р±РѕСЂРєРµ.
# * Р”Р°РІР°С‚СЊ РїРѕР»РµР·РЅС‹Рµ СЂРµРєРѕРјРјРµРЅРґР°С†РёРё РїРѕР»СЊР·РѕРІР°С‚РµР»СЏРј СЃ РјР°Р»С‹Рј С‡РёСЃР»РѕРј Р»Р°Р№РєРѕРІ С‚РѕР¶Рµ РјРѕР¶РЅРѕ: РЅР°РїСЂРёРјРµСЂ, РјРѕР¶РЅРѕ РІС‹РґР°РІР°С‚СЊ РЅР°РёР±РѕР»РµРµ РїРѕРїСѓР»СЏСЂРЅС‹Рµ РІ С†РµР»РѕРј С„РёР»СЊРјС‹.
# * Р Р°Р·РґРµР»РµРЅРёРµ РЅР° РѕР±СѓС‡РµРЅРёРµ/С‚РµСЃС‚ С‡РµСЃС‚РЅРµРµ РґРµР»Р°С‚СЊ РЅР° РїРѕ РІСЂРµРјРµРЅРё: РїРµСЂРІС‹Рµ 70% (РЅР°РїСЂРёРјРµСЂ) Р»Р°Р№РєРѕРІ РІ РѕР±СѓС‡РµРЅРёРµ, РѕСЃС‚Р°Р»СЊРЅС‹Рµ РІ С‚РµСЃС‚. Р­С‚Рѕ Р±Р»РёР¶Рµ Рє СЂРµР°Р»СЊРЅРѕР№ Р¶РёР·РЅРё, РєРѕРіРґР° РІС‹ СЃРЅР°С‡Р°Р»Р° РѕР±СѓС‡Р°РµС‚Рµ РјРѕРґРµР»СЊ РЅР° Р»РѕРіР°С…, Р° РїРѕС‚РѕРј РїСЂРёРјРµРЅСЏРµС‚Рµ РЅР° РЅРѕРІС‹С… СЃРµСЃСЃРёСЏС… РїРѕР»СЊР·РѕРІР°С‚РµР»РµР№.
